# %% [markdown]
# # Title : Exploratory Data Analysis On UPI
#
# I select this particular project because i am curious about what kind of data handling done here by experties and because there are some related like upi `(google pay , paytm , phone pay)` apps are present in the market.
#
# This dataset is extracted from the official website of UPI. It contains details from AUG-16 to FEB-20.
# https://www.kaggle.com/lazycipher/upi-usage-statistics-aug16-to-feb20
#
# There are several options for getting the dataset into Jupyter:
#
# Download the `CSV` manually and upload it via `Jupyter's GUI`
#
# Use the urlretrieve function from the urllib.request to download CSV files from a raw URL directly
# Use a helper library `e.g. opendatasets`, which contains a collection of curated datasets and provides a function for directly download.

# %%
# Acording to the requirement we can import different types of libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !pip install jovian --upgrade -q

# %% [markdown]
#    Upload the data by using `(pd.read_csv("file Name"))`

# %%
# the code we are using to import the data file is changes acording to the file format and wether it is downloaded
UPI_data_df = pd.read_csv("UPIData.csv")

# %%
UPI_data_df
# Out:
#    Month-Year Month  Year  No.Of.Banks.Using.Upi  Volume.Of.Transaction.in.Mn  \
# 0      Feb-20   Feb  2020                    146                     1323.280
# 1      Jan-20   Jan  2020                    144                     1305.020
# 2      Dec-19   Dec  2019                    143                     1308.400
# 3      Nov-19   Nov  2019                    143                     1218.770
# 4      Oct-19   Oct  2019                    141                     1148.360
# 5     Sept-19  Sept  2019                    141                      955.020
# 6      Aug-19   Aug  2019                    141                      918.350
# 7     July-19  July  2019                    143                      822.290
# 8     June-19  June  2019                    142                      754.540
# 9      May-19   May  2019                    143                      733.540
# 10     Apr-19   Apr  2019                    144                      781.790
# ...

# %% [markdown]
#  with the healp of `.info` we can find the null values in the data frame.

# %%
# we can use .nfo methode to find out the data type 
UPI_data_df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Month-Year                   43 non-null     object
#  1   Month                        43 non-null     object
#  2   Year                         43 non-null     int64
#  3   No.Of.Banks.Using.Upi        43 non-null     int64
#  4   Volume.Of.Transaction.in.Mn  43 non-null     float64
#  5   Amount.Of.Transaction        43 non-null     object
#  6   Amount.Of.Transaction.In.Bn  43 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# To know the which columns are present in the data file `'.columns'`

# %%
# By usig .coloumns we can easily see the type of coloumns in the data frame
UPI_data_df.columns
# Out:
# Index(['Month-Year', 'Month', 'Year', 'No.Of.Banks.Using.Upi',
#        'Volume.Of.Transaction.in.Mn', 'Amount.Of.Transaction',
#        'Amount.Of.Transaction.In.Bn'],
#       dtype='object')

# %% [markdown]
# To calculate the number of columns and row `('.shap')`

# %%
# To find out the no of coloumns and row in the data we can use .shape methode
UPI_data_df.shape
# Out:
# (43, 7)

# %%
project_name = "EDA_on_UPI"

# %%
# !pip install jovian --upgrade -q

# %% [markdown]
# Whether you're running this Jupyter notebook on an online service like Binder or on your local machine, it's important to save your work from time, so that you can access it later, or share it online. You can upload this notebook to your Jovian.ml account using the jovian Python library.

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "dhirendrapathak63/eda-on-upi" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/dhirendrapathak63/eda-on-upi
# 'https://jovian.ml/dhirendrapathak63/eda-on-upi'

# %% [markdown]
# # Data Preparation and Cleaning

# %% [markdown]
# To find the length of the data we use `len()` Function

# %%
#To find the length of the data we use `len()` Function
len(UPI_data_df)
# Out:
# 43

# %% [markdown]
# In this case we dont want to mess with the real data so awoid this isue we can create a copy file by using  `'copy()'`function.

# %%
#To make a copy of dataset we use .copy 
#here we are storing our data into UPI_df
UPI_df = UPI_data_df.copy();

# %%
UPI_df
# Out:
#    Month-Year Month  Year  No.Of.Banks.Using.Upi  Volume.Of.Transaction.in.Mn  \
# 0      Feb-20   Feb  2020                    146                     1323.280
# 1      Jan-20   Jan  2020                    144                     1305.020
# 2      Dec-19   Dec  2019                    143                     1308.400
# 3      Nov-19   Nov  2019                    143                     1218.770
# 4      Oct-19   Oct  2019                    141                     1148.360
# 5     Sept-19  Sept  2019                    141                      955.020
# 6      Aug-19   Aug  2019                    141                      918.350
# 7     July-19  July  2019                    143                      822.290
# 8     June-19  June  2019                    142                      754.540
# 9      May-19   May  2019                    143                      733.540
# 10     Apr-19   Apr  2019                    144                      781.790
# ...

# %% [markdown]
# The Dataset conatain over 42 months of data in which the usage of UPI acording to the month is classified .
#
# in this datset we can see the no of columns included and the no of raws . which conatain the above data.
#  as wew can see the year passes the no of banks used upi is also get increased.

# %% [markdown]
# By using `info ( )` we can find the Dtypes , size of the data, etc.

# %%
# we can use .nfo methode to find out the data type
UPI_df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Month-Year                   43 non-null     object
#  1   Month                        43 non-null     object
#  2   Year                         43 non-null     int64
#  3   No.Of.Banks.Using.Upi        43 non-null     int64
#  4   Volume.Of.Transaction.in.Mn  43 non-null     float64
#  5   Amount.Of.Transaction        43 non-null     object
#  6   Amount.Of.Transaction.In.Bn  43 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# In our dataset we dont have any `null values` so there is no need to classify the null values and making changes into the dataset.
#
#   if we found any type of null value here then we have to check it wether it is some type of data error or something else
#   and then provide avg value or set it as a null value to avoid errors

# %% [markdown]
# ## To change data on particular location is done by using  `.loc [ ]`. in this case we want sept as sep.

# %%
#To change data on particular location is done by using .loc [ ]
UPI_df.loc[5,'Month-Year'] = 'Sep-19'

# %% [markdown]
# Replace function is used to change the particular data with required data. it can be done by `.replace ( )`

# %%
#Replace function is used to change the particular data with required data. it can be done by .replace ( )
UPI_df['Month-Year'] = UPI_df['Month-Year'].replace(['June-17','July-17','June-18','July-18','June-19','July-19'],['Jun-17','Jul-17','Jun-18','Jul-18','Jun-19','Jul-19'])

# %%
UPI_df['Month-Year']
# Out:
# 0     Feb-20
# 1     Jan-20
# 2     Dec-19
# 3     Nov-19
# 4     Oct-19
# 5     Sep-19
# 6     Aug-19
# 7     Jul-19
# 8     Jun-19
# 9     May-19
# 10    Apr-19
# 11    Mar-19
# 12    Feb-19
# 13    Jan-19
# 14    Dec-18
# 15    Nov-18
# 16    Oct-18
# 17    Sep-18
# 18    Aug-18
# 19    Jul-18
# 20    Jun-18
# 21    May-18
# 22    Apr-18
# 23    Mar-18
# 24    Feb-18
# 25    Jan-18
# 26    Dec-17
# 27    Nov-17
# 28    Oct-17
# 29    Sep-17
# 30    Aug-17
# 31    Jul-17
# 32    Jun-17
# 33    May-17
# 34    Apr-17
# 35    Mar-17
# 36    Feb-17
# 37    Jan-17
# 38    Dec-16
# 39    Nov-16
# 40    Oct-16
# 41    Sep-16
# 42    Aug-16
# Name: Month-Year, dtype: object

# %% [markdown]
# Here we found the in month-year column we have four digits as we known that the month is always in three digits
#
# so to avoid the errors we can change it by using `.replace` function.

# %%
#changing the datatype (depends on the datatype)
UPI_df['Month-Year'] = pd.to_datetime(UPI_df['Month-Year'],format='%b-%y')

# %%
UPI_df['Month-Year']
# Out:
# 0    2020-02-01
# 1    2020-01-01
# 2    2019-12-01
# 3    2019-11-01
# 4    2019-10-01
# 5    2019-09-01
# 6    2019-08-01
# 7    2019-07-01
# 8    2019-06-01
# 9    2019-05-01
# 10   2019-04-01
# 11   2019-03-01
# 12   2019-02-01
# 13   2019-01-01
# 14   2018-12-01
# 15   2018-11-01
# 16   2018-10-01
# 17   2018-09-01
# 18   2018-08-01
# 19   2018-07-01
# 20   2018-06-01
# 21   2018-05-01
# 22   2018-04-01
# 23   2018-03-01
# 24   2018-02-01
# 25   2018-01-01
# 26   2017-12-01
# 27   2017-11-01
# 28   2017-10-01
# 29   2017-09-01
# 30   2017-08-01
# 31   2017-07-01
# 32   2017-06-01
# 33   2017-05-01
# 34   2017-04-01
# 35   2017-03-01
# 36   2017-02-01
# 37   2017-01-01
# 38   2016-12-01
# 39   2016-11-01
# 40   2016-10-01
# 41   2016-09-01
# 42   2016-08-01
# Name: Month-Year, dtype: datetime64[ns]

# %% [markdown]
# This case we want month year in datetime formate so doing that we are using  `pd.to_datetime ()`

# %%
#To check the dtype of particular column 
UPI_df['Month'].dtype
# Out:
# dtype('O')

# %%
UPI_df['Amount.Of.Transaction'].dtype
# Out:
# dtype('O')

# %%
UPI_df['Amount.Of.Transaction'] = UPI_df['Amount.Of.Transaction'].str.replace(',','')

# %%
UPI_df['Amount.Of.Transaction']
# Out:
# 0     221995.42
# 1     216242.97
# 2     202520.76
# 3     189229.09
# 4     191359.94
# 5     161456.56
# 6     154504.89
# 7     146386.64
# 8     146566.35
# 9     152449.29
# 10    142034.39
# 11    133460.72
# 12    106737.12
# 13    109932.43
# 14    102594.82
# 15     82232.21
# 16     74978.27
# 17     59835.36
# 18     54212.26
# 19     51843.14
# 20     40834.03
# 21     33288.51
# 22     27021.85
# 23     24172.60
# 24     19126.20
# 25     15571.20
# 26     13144.30
# 27      9640.60
# 28      7057.80
# 29      5293.40
# 30      4127.20
# 31      3381.20
# 32      3067.10
# 33      2765.40
# 34      2240.80
# 35      2391.40
# 36      1902.10
# 37      1658.80
# 38       706.20
# 39       100.50
# 40        48.60
# 41        32.60
# 42         3.10
# Name: Amount.Of.Transaction, dtype: object

# %%
UPI_df['Amount.Of.Transaction'] = UPI_df['Amount.Of.Transaction'].astype(float)

# %%
UPI_df['Amount.Of.Transaction']
# Out:
# 0     221995.42
# 1     216242.97
# 2     202520.76
# 3     189229.09
# 4     191359.94
# 5     161456.56
# 6     154504.89
# 7     146386.64
# 8     146566.35
# 9     152449.29
# 10    142034.39
# 11    133460.72
# 12    106737.12
# 13    109932.43
# 14    102594.82
# 15     82232.21
# 16     74978.27
# 17     59835.36
# 18     54212.26
# 19     51843.14
# 20     40834.03
# 21     33288.51
# 22     27021.85
# 23     24172.60
# 24     19126.20
# 25     15571.20
# 26     13144.30
# 27      9640.60
# 28      7057.80
# 29      5293.40
# 30      4127.20
# 31      3381.20
# 32      3067.10
# 33      2765.40
# 34      2240.80
# 35      2391.40
# 36      1902.10
# 37      1658.80
# 38       706.20
# 39       100.50
# 40        48.60
# 41        32.60
# 42         3.10
# Name: Amount.Of.Transaction, dtype: float64

# %% [markdown]
# Now here we want some random data from our dataseat so doing that we can use ( .sample ( ) ) and we can pick some random data

# %%
UPI_df.sample(10)
# Out:
#    Month-Year Month  Year  No.Of.Banks.Using.Upi  Volume.Of.Transaction.in.Mn  \
# 2  2019-12-01   Dec  2019                    143                     1308.400
# 22 2018-04-01   Apr  2018                     97                      190.080
# 39 2016-11-01   Nov  2016                     30                        0.285
# 4  2019-10-01   Oct  2019                    141                     1148.360
# 6  2019-08-01   Aug  2019                    141                      918.350
# 1  2020-01-01   Jan  2020                    144                     1305.020
# 19 2018-07-01  July  2018                    114                      273.750
# 5  2019-09-01  Sept  2019                    141                      955.020
# 29 2017-09-01  Sept  2017                     57                       30.778
# 13 2019-01-01   Jan  2019                    134                      672.750
#
#     Amount.Of.Transaction  Amount.Of.Transaction.In.Bn
# 2               202520.76                    2025.2076
# ...

# %% [markdown]
# Here we can use `.sample()` to select a random data for calculating the % of error or to calculate the acuraccy rate of the data.
#
#
# Note : Whenever we are geting a sample of data to calculate the acuraccy rate always select a random values if we select a data with a particular requirement then it will notify as a biased data so always select a random values.

# %%
# Here we want to know Total values of each column this done by using  .describe ( ) 
UPI_df.describe()
# Out:
#               Year  No.Of.Banks.Using.Upi  Volume.Of.Transaction.in.Mn  \
# count    43.000000              43.000000                    43.000000
# mean   2017.860465              93.953488                   409.102326
# std       1.103704              44.269173                   435.248671
# min    2016.000000              21.000000                     0.085000
# 25%    2017.000000              52.500000                    10.799500
# 50%    2018.000000             101.000000                   190.080000
# 75%    2019.000000             141.000000                   744.040000
# max    2020.000000             146.000000                  1323.280000
#
#        Amount.Of.Transaction  Amount.Of.Transaction.In.Bn
# count              43.000000                    43.000000
# mean            67863.909767                   678.639098
# std             73391.238261                   733.912383
# min                 3.100000                     0.031000
# ...

# %% [markdown]
# By using .describe() we can calculate the percentile , mean , min , max as we can see in the table.

# %%
#`.unique` is used to find the dtype 
UPI_df['Month'].unique()
# Out:
# array(['Feb', 'Jan', 'Dec', 'Nov', 'Oct', 'Sept', 'Aug', 'July', 'June',
#        'May', 'Apr', 'Mar'], dtype=object)

# %%
UPI_df['Month-Year'].unique()
# Out:
# array(['2020-02-01T00:00:00.000000000', '2020-01-01T00:00:00.000000000',
#        '2019-12-01T00:00:00.000000000', '2019-11-01T00:00:00.000000000',
#        '2019-10-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#        '2019-08-01T00:00:00.000000000', '2019-07-01T00:00:00.000000000',
#        '2019-06-01T00:00:00.000000000', '2019-05-01T00:00:00.000000000',
#        '2019-04-01T00:00:00.000000000', '2019-03-01T00:00:00.000000000',
#        '2019-02-01T00:00:00.000000000', '2019-01-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-11-01T00:00:00.000000000',
#        '2018-10-01T00:00:00.000000000', '2018-09-01T00:00:00.000000000',
#        '2018-08-01T00:00:00.000000000', '2018-07-01T00:00:00.000000000',
#        '2018-06-01T00:00:00.000000000', '2018-05-01T00:00:00.000000000',
#        '2018-04-01T00:00:00.000000000', '2018-03-01T00:00:00.000000000',
#        '2018-02-01T00:00:00.000000000', '2018-01-01T00:00:00.000000000',
# ...

# %%
UPI_df['Volume.Of.Transaction.in.Mn'].unique()
# Out:
# array([1.32328e+03, 1.30502e+03, 1.30840e+03, 1.21877e+03, 1.14836e+03,
#        9.55020e+02, 9.18350e+02, 8.22290e+02, 7.54540e+02, 7.33540e+02,
#        7.81790e+02, 7.99540e+02, 6.74190e+02, 6.72750e+02, 6.20170e+02,
#        5.24940e+02, 4.82360e+02, 4.05870e+02, 3.12020e+02, 2.73750e+02,
#        2.46370e+02, 1.89480e+02, 1.90080e+02, 1.78050e+02, 1.71400e+02,
#        1.51833e+02, 1.45463e+02, 1.04841e+02, 7.67720e+01, 3.07780e+01,
#        1.66080e+01, 1.14440e+01, 1.01550e+01, 9.16800e+00, 7.00500e+00,
#        6.16100e+00, 4.15600e+00, 4.15300e+00, 1.96700e+00, 2.85000e-01,
#        1.03000e-01, 8.50000e-02, 9.30000e-02])

# %%
UPI_df['No.Of.Banks.Using.Upi'].unique()
# Out:
# array([146, 144, 143, 141, 142, 139, 134, 129, 128, 122, 114, 110, 101,
#         97,  91,  86,  71,  67,  61,  60,  57,  55,  53,  52,  49,  48,
#         44,  36,  35,  30,  26,  25,  21], dtype=int64)

# %%
UPI_df['Amount.Of.Transaction'].unique()
# Out:
# array([2.2199542e+05, 2.1624297e+05, 2.0252076e+05, 1.8922909e+05,
#        1.9135994e+05, 1.6145656e+05, 1.5450489e+05, 1.4638664e+05,
#        1.4656635e+05, 1.5244929e+05, 1.4203439e+05, 1.3346072e+05,
#        1.0673712e+05, 1.0993243e+05, 1.0259482e+05, 8.2232210e+04,
#        7.4978270e+04, 5.9835360e+04, 5.4212260e+04, 5.1843140e+04,
#        4.0834030e+04, 3.3288510e+04, 2.7021850e+04, 2.4172600e+04,
#        1.9126200e+04, 1.5571200e+04, 1.3144300e+04, 9.6406000e+03,
#        7.0578000e+03, 5.2934000e+03, 4.1272000e+03, 3.3812000e+03,
#        3.0671000e+03, 2.7654000e+03, 2.2408000e+03, 2.3914000e+03,
#        1.9021000e+03, 1.6588000e+03, 7.0620000e+02, 1.0050000e+02,
#        4.8600000e+01, 3.2600000e+01, 3.1000000e+00])

# %%
UPI_df['Amount.Of.Transaction.In.Bn'].unique()
# Out:
# array([2.2199542e+03, 2.1624297e+03, 2.0252076e+03, 1.8922909e+03,
#        1.9135994e+03, 1.6145656e+03, 1.5450489e+03, 1.4638664e+03,
#        1.4656635e+03, 1.5244929e+03, 1.4203439e+03, 1.3346072e+03,
#        1.0673712e+03, 1.0993243e+03, 1.0259482e+03, 8.2232210e+02,
#        7.4978270e+02, 5.9835360e+02, 5.4212260e+02, 5.1843140e+02,
#        4.0834030e+02, 3.3288510e+02, 2.7021850e+02, 2.4172600e+02,
#        1.9126200e+02, 1.5571200e+02, 1.3144300e+02, 9.6406000e+01,
#        7.0578000e+01, 5.2934000e+01, 4.1272000e+01, 3.3812000e+01,
#        3.0671000e+01, 2.7654000e+01, 2.2408000e+01, 2.3914000e+01,
#        1.9021000e+01, 1.6588000e+01, 7.0620000e+00, 1.0050000e+00,
#        4.8600000e-01, 3.2600000e-01, 3.1000000e-02])

# %% [markdown]
# Here our data cleaning is completed. now we can go for data visualization.
#
# as we find out our data has no null values so we dont need to change anything in our values.
#
# But we have to set over data clean for further use so we changed it acording to the format now we can go for
# `Exploratory Analysis and Visualization`

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "dhirendrapathak63/eda-on-upi" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/dhirendrapathak63/eda-on-upi
# 'https://jovian.ml/dhirendrapathak63/eda-on-upi'

# %% [markdown]
# #  Exploratory Analysis and Visualization

# %% [markdown]
#  Know About Data visualization:
#
# The Data visualization is the graphic representation of data.
# It involves producing images that communicate relationships among the represented data to viewers.
# Visualizing data is an essential part of data analysis and machine learning.
# In this tutorial, we'll use Python libraries Matplotlib and Seaborn to learn and apply some popular data visualization techniques.

# %%
UPI_df
# Out:
#    Month-Year Month  Year  No.Of.Banks.Using.Upi  Volume.Of.Transaction.in.Mn  \
# 0  2020-02-01   Feb  2020                    146                     1323.280
# 1  2020-01-01   Jan  2020                    144                     1305.020
# 2  2019-12-01   Dec  2019                    143                     1308.400
# 3  2019-11-01   Nov  2019                    143                     1218.770
# 4  2019-10-01   Oct  2019                    141                     1148.360
# 5  2019-09-01  Sept  2019                    141                      955.020
# 6  2019-08-01   Aug  2019                    141                      918.350
# 7  2019-07-01  July  2019                    143                      822.290
# 8  2019-06-01  June  2019                    142                      754.540
# 9  2019-05-01   May  2019                    143                      733.540
# 10 2019-04-01   Apr  2019                    144                      781.790
# ...

# %%
UPI_df['Month-Year'].unique()
# Out:
# array(['2020-02-01T00:00:00.000000000', '2020-01-01T00:00:00.000000000',
#        '2019-12-01T00:00:00.000000000', '2019-11-01T00:00:00.000000000',
#        '2019-10-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#        '2019-08-01T00:00:00.000000000', '2019-07-01T00:00:00.000000000',
#        '2019-06-01T00:00:00.000000000', '2019-05-01T00:00:00.000000000',
#        '2019-04-01T00:00:00.000000000', '2019-03-01T00:00:00.000000000',
#        '2019-02-01T00:00:00.000000000', '2019-01-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-11-01T00:00:00.000000000',
#        '2018-10-01T00:00:00.000000000', '2018-09-01T00:00:00.000000000',
#        '2018-08-01T00:00:00.000000000', '2018-07-01T00:00:00.000000000',
#        '2018-06-01T00:00:00.000000000', '2018-05-01T00:00:00.000000000',
#        '2018-04-01T00:00:00.000000000', '2018-03-01T00:00:00.000000000',
#        '2018-02-01T00:00:00.000000000', '2018-01-01T00:00:00.000000000',
# ...

# %%
UPI_df['Month-Year'].shape
# Out:
# (43,)

# %%
 #Top 10 Amount of transaction
UPI = UPI_df['Amount.Of.Transaction'].head(10)

# %%
UPI
# Out:
# 0    221995.42
# 1    216242.97
# 2    202520.76
# 3    189229.09
# 4    191359.94
# 5    161456.56
# 6    154504.89
# 7    146386.64
# 8    146566.35
# 9    152449.29
# Name: Amount.Of.Transaction, dtype: float64

# %%
UPI_df['Month-Year'].head(10)
# Out:
# 0   2020-02-01
# 1   2020-01-01
# 2   2019-12-01
# 3   2019-11-01
# 4   2019-10-01
# 5   2019-09-01
# 6   2019-08-01
# 7   2019-07-01
# 8   2019-06-01
# 9   2019-05-01
# Name: Month-Year, dtype: datetime64[ns]

# %%
High_tran_10_with_DATE = UPI_df[['Amount.Of.Transaction','Month-Year']]

# %%
#here Inplace is used to make changes in original data
High_tran_10_with_DATE.set_index('Month-Year',inplace=True)

# %%
High_tran_10_with_DATE
# Out:
#             Amount.Of.Transaction
# Month-Year
# 2020-02-01              221995.42
# 2020-01-01              216242.97
# 2019-12-01              202520.76
# 2019-11-01              189229.09
# 2019-10-01              191359.94
# 2019-09-01              161456.56
# 2019-08-01              154504.89
# 2019-07-01              146386.64
# 2019-06-01              146566.35
# 2019-05-01              152449.29
# 2019-04-01              142034.39
# 2019-03-01              133460.72
# 2019-02-01              106737.12
# 2019-01-01              109932.43
# 2018-12-01              102594.82
# 2018-11-01               82232.21
# 2018-10-01               74978.27
# 2018-09-01               59835.36
# 2018-08-01               54212.26
# 2018-07-01               51843.14
# 2018-06-01               40834.03
# 2018-05-01               33288.51
# 2018-04-01               27021.85
# 2018-03-01               24172.60
# 2018-02-01               19126.20
# 2018-01-01               15571.20
# ...

# %%
#here we are making a graphical representation of our datset using plt.plot 
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.plot(High_tran_10_with_DATE.index,High_tran_10_with_DATE,marker='o')
plt.title('UPI Chart')
plt.xlabel('Month-year')
plt.ylabel('Amount.Of.Transaction')
plt.show()

# %% [markdown]
# Here we are using `plt.plot` function where we can check the graphical representaion of our datset.
# Here we can plot multiple lines acording to the vizualisation or representaiton we want.
# The plt.plot function supports many arguments for styling lines and markers:
#
# color or c: set the color of the line (supported colors)
#
# linestyle or ls: choose between a solid or dashed line
#
# linewidth or lw: set the width of a line
#
# markersize or ms: set the size of markers
#
# markeredgecolor or mec: set the edge color for markers
#
# markeredgewidth or mew: set the edge width for markers
#
#
# markerfacecolor or mfc: set the fill color for markers
#
# alpha: opacity of the plot

# %%
plt.figure(figsize=(25,8), dpi= 80)
plt.grid(True)
plt.plot(UPI_df['Amount.Of.Transaction.In.Bn'],label= 'Amount')
plt.plot(UPI_df['Volume.Of.Transaction.in.Mn'],label= 'Volume')
plt.legend(bbox_to_anchor =(1.0, 1.025), ncol = 2);

# %%
plt.figure(figsize=(10,7))
x = UPI_df['No.Of.Banks.Using.Upi']
y = UPI_df['Amount.Of.Transaction.In.Bn']
plt.title('Amount.Of.Transaction.In.Bn')
plt.hist2d(x, y, bins=10, cmap='hot_r')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
UPI_df['Month-Year'],['Amount.Of.Transaction']
# Out:
# (0    2020-02-01
#  1    2020-01-01
#  2    2019-12-01
#  3    2019-11-01
#  4    2019-10-01
#  5    2019-09-01
#  6    2019-08-01
#  7    2019-07-01
#  8    2019-06-01
#  9    2019-05-01
#  10   2019-04-01
#  11   2019-03-01
#  12   2019-02-01
#  13   2019-01-01
#  14   2018-12-01
#  15   2018-11-01
#  16   2018-10-01
#  17   2018-09-01
#  18   2018-08-01
#  19   2018-07-01
#  20   2018-06-01
#  21   2018-05-01
#  22   2018-04-01
#  23   2018-03-01
#  24   2018-02-01
#  25   2018-01-01
#  26   2017-12-01
#  27   2017-11-01
#  28   2017-10-01
#  29   2017-09-01
#  30   2017-08-01
#  31   2017-07-01
#  32   2017-06-01
#  33   2017-05-01
#  34   2017-04-01
#  35   2017-03-01
#  36   2017-02-01
#  37   2017-01-01
#  38   2016-12-01
#  39   2016-11-01
#  40   2016-10-01
#  41   2016-09-01
#  42   2016-08-01
#  Name: Month-Year, dtype: datetime64[ns],
#  ['Amount.Of.Transaction'])

# %%
Month = UPI_df['Month-Year']

# %%
Month
# Out:
# 0    2020-02-01
# 1    2020-01-01
# 2    2019-12-01
# 3    2019-11-01
# 4    2019-10-01
# 5    2019-09-01
# 6    2019-08-01
# 7    2019-07-01
# 8    2019-06-01
# 9    2019-05-01
# 10   2019-04-01
# 11   2019-03-01
# 12   2019-02-01
# 13   2019-01-01
# 14   2018-12-01
# 15   2018-11-01
# 16   2018-10-01
# 17   2018-09-01
# 18   2018-08-01
# 19   2018-07-01
# 20   2018-06-01
# 21   2018-05-01
# 22   2018-04-01
# 23   2018-03-01
# 24   2018-02-01
# 25   2018-01-01
# 26   2017-12-01
# 27   2017-11-01
# 28   2017-10-01
# 29   2017-09-01
# 30   2017-08-01
# 31   2017-07-01
# 32   2017-06-01
# 33   2017-05-01
# 34   2017-04-01
# 35   2017-03-01
# 36   2017-02-01
# 37   2017-01-01
# 38   2016-12-01
# 39   2016-11-01
# 40   2016-10-01
# 41   2016-09-01
# 42   2016-08-01
# Name: Month-Year, dtype: datetime64[ns]

# %%
Amount = UPI_df['Amount.Of.Transaction']

# %%
Amount
# Out:
# 0     221995.42
# 1     216242.97
# 2     202520.76
# 3     189229.09
# 4     191359.94
# 5     161456.56
# 6     154504.89
# 7     146386.64
# 8     146566.35
# 9     152449.29
# 10    142034.39
# 11    133460.72
# 12    106737.12
# 13    109932.43
# 14    102594.82
# 15     82232.21
# 16     74978.27
# 17     59835.36
# 18     54212.26
# 19     51843.14
# 20     40834.03
# 21     33288.51
# 22     27021.85
# 23     24172.60
# 24     19126.20
# 25     15571.20
# 26     13144.30
# 27      9640.60
# 28      7057.80
# 29      5293.40
# 30      4127.20
# 31      3381.20
# 32      3067.10
# 33      2765.40
# 34      2240.80
# 35      2391.40
# 36      1902.10
# 37      1658.80
# 38       706.20
# 39       100.50
# 40        48.60
# 41        32.60
# 42         3.10
# Name: Amount.Of.Transaction, dtype: float64

# %%
No = UPI_df['No.Of.Banks.Using.Upi']

# %%
No
# Out:
# 0     146
# 1     144
# 2     143
# 3     143
# 4     141
# 5     141
# 6     141
# 7     143
# 8     142
# 9     143
# 10    144
# 11    142
# 12    139
# 13    134
# 14    129
# 15    128
# 16    128
# 17    122
# 18    114
# 19    114
# 20    110
# 21    101
# 22     97
# 23     91
# 24     86
# 25     71
# 26     67
# 27     61
# 28     60
# 29     57
# 30     55
# 31     53
# 32     52
# 33     49
# 34     48
# 35     44
# 36     44
# 37     36
# 38     35
# 39     30
# 40     26
# 41     25
# 42     21
# Name: No.Of.Banks.Using.Upi, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.set_style("whitegrid")
plt.plot(Month,Amount)
plt.xlabel('Month-year')
plt.ylabel('Amount.Of.Transaction')
plt.plot(Month, Amount, 'or')
plt.legend(['Amount']);

# %% [markdown]
# An easy way to make your charts look beautiful is to use some default styles provided in the Seaborn library. These can be applied globally using the sns.set_style function. You can see a full list of predefined styles here.
#
# https://seaborn.pydata.org/generated/seaborn.set_style.html
#
#    Here we are cheking the Amount.Of.Transaction vs Month-year

# %%
plt.figure(figsize=(12,6))
sns.set_style("darkgrid")
plt.plot(Month,No)
plt.plot(Month, No, 's-b')
plt.xlabel('Month-Year')
plt.ylabel('No.Of.Banks.Using.Upi')
plt.legend(['No.Of.Banks.Using.Upi']);

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(No , Amount,hue=No, s=100);

# %% [markdown]
# You can also edit default styles directly by modifying the matplotlib.rcParams dictionary.
#
#  https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html#matplotlib-rcparams

# %%
plt.figure(figsize=(25,10))
sns.countplot('Year',data=UPI_df)
plt.title('Highest transaction per year')
plt.show()

# %%
#to plot the data in the bars we can use plt.hist function
plt.figure(figsize=(12,6))
plt.title('Amount of transaction')
plt.hist(Amount ,bins=5 ,color='orange');

# %% [markdown]
# Here we can see the biger bar and by seeing this we can imediately identify the largest amount.

# %%
#To heighlight the selected data we can use above fuction
def hover(hover_color="#ffff99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "150%"),
                               ("text-align", "center")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]
html = (UPI_df.style.set_table_styles(styles)
          .set_caption("Hover to highlight."))
html
# Out:
# <style  type="text/css" >
#     #T_6a2f85f1_02bf_11eb_97e8_d02788d48bfe tr:hover {
#           background-color: #ffff99;
#     }    #T_6a2f85f1_02bf_11eb_97e8_d02788d48bfe th {
#           font-size: 150%;
#           text-align: center;
#     }    #T_6a2f85f1_02bf_11eb_97e8_d02788d48bfe caption {
#           caption-side: bottom;
#     }</style><table id="T_6a2f85f1_02bf_11eb_97e8_d02788d48bfe" ><caption>Hover to highlight.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Month-Year</th>        <th class="col_heading level0 col1" >Month</th>        <th class="col_heading level0 col2" >Year</th>        <th class="col_heading level0 col3" >No.Of.Banks.Using.Upi</th>        <th class="col_heading level0 col4" >Volume.Of.Transaction.in.Mn</th>        <th class="col_heading level0 col5" >Amount.Of.Transaction</th>        <th class="col_heading level0 col6" >Amount.Of.Transaction.In.Bn</th>    </tr></thead><tbody>
# ...

# %% [markdown]
# Here we can see the data get heighlighted whenever we drag a curser on it by using this we can easily see the data contained by the given coloumn.

# %%
plt.figure(figsize=(12,6))
sns.set_style("darkgrid")
plt.xlabel('Month-Year')
plt.ylabel('Amount.Of.Transaction')
plt.bar(Month, Amount);

# %%
sns.pairplot(UPI_df);

# %% [markdown]
# Seaborn also provides a helper function sns.pairplot to automatically plot different types of charts for pairs of features within a dataframe.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "dhirendrapathak63/eda-on-upi" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/dhirendrapathak63/eda-on-upi
# 'https://jovian.ml/dhirendrapathak63/eda-on-upi'

# %% [markdown]
# ## Asking and Answering Questions

# %% [markdown]
# # Q1. In which year the highest noumber of banks started using the `UPI` ?

# %%
UPI_df;

# %%
plt.figure(figsize=(12,6))
plt.xlabel('No.Of.Banks.Using.Upi')
plt.ylabel('Month-Year')
plt.plot(No,Month);

# %% [markdown]
# ### Here we can see in the eareliar stages no of banks which uses Up  is low as we can see in the graph .
# ### when the time geting passes the no of banks which started use of upi is get increased in the mean time in 2019 the banks started
# using upi is suddenly get increased.
#
#    (1) By using `plt.plot` we can visualize the graph of data.
#
#    (2) Here we can also put the specif column and see what if the graph goes `increasing` or `decreasing`

# %% [markdown]
# # Q2. Set the UPI data in Styler.set_properties form ?

# %%
UPI_df.style.set_properties(**{'background-color': 'black',
                            'color': 'lawngreen',
                            'border-color': 'black'})
# Out:
# <style  type="text/css" >
#     #T_7d2147fb_02bf_11eb_a24e_d02788d48bferow0_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  black;
#         }    #T_7d2147fb_02bf_11eb_a24e_d02788d48bferow0_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  black;
#         }    #T_7d2147fb_02bf_11eb_a24e_d02788d48bferow0_col2 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  black;
#         }    #T_7d2147fb_02bf_11eb_a24e_d02788d48bferow0_col3 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  black;
#         }    #T_7d2147fb_02bf_11eb_a24e_d02788d48bferow0_col4 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  black;
#         }    #T_7d2147fb_02bf_11eb_a24e_d02788d48bferow0_col5 {
#             background-color:  black;
# ...

# %% [markdown]
# ## Here we are using `.style.set_properties` to set the data in a specific format

# %% [markdown]
# # Q3. What is the order of `no of banks using upi` in per year is it decreasing or increasing as per the data ?

# %%
sns.light_palette("red", as_cmap=True)

UPI_df.style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
#     #T_7d414e0d_02bf_11eb_87d4_d02788d48bferow0_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_7d414e0d_02bf_11eb_87d4_d02788d48bferow0_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_7d414e0d_02bf_11eb_87d4_d02788d48bferow0_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_7d414e0d_02bf_11eb_87d4_d02788d48bferow0_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_7d414e0d_02bf_11eb_87d4_d02788d48bferow0_col6 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_7d414e0d_02bf_11eb_87d4_d02788d48bferow1_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_7d414e0d_02bf_11eb_87d4_d02788d48bferow1_col3 {
#             background-color:  #f4e61e;
#             color:  #000000;
# ...

# %% [markdown]
# ### The data is set in the year wise distribution to set the data in the incrasing form or mesmerising it into year wise we can use `sns.light_palette`.
# (1) as we can see the no of banks using upi is get increased in 2017 but the transaction amount is still low.
#
# (2) The transaction amount is get sudden increased after dec 2018
#
#    By using `sns.light_palette` we can vizualise data in easyist form as we can see in the graph.

# %% [markdown]
# # Q4. Set the No Of Banks Using Upi vs Amount Of Transaction In Bn in the data    set ?

# %%
UPI_df.style.bar(subset=['No.Of.Banks.Using.Upi', 'Amount.Of.Transaction.In.Bn'], color='#5fba7d')
# Out:
# <style  type="text/css" >
#     #T_efd5185d_02bf_11eb_9e5d_d02788d48bferow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_efd5185d_02bf_11eb_9e5d_d02788d48bferow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_efd5185d_02bf_11eb_9e5d_d02788d48bferow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 98.4%, transparent 98.4%);
#         }    #T_efd5185d_02bf_11eb_9e5d_d02788d48bferow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 97.4%, transparent 97.4%);
#         }    #T_efd5185d_02bf_11eb_9e5d_d02788d48bferow2_col3 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# # Q5. How to aggregate the mean, minimum, maximum based on amount of transaction ?

# %%
UPI_df.sample(5).describe()
# Out:
#              Year  No.Of.Banks.Using.Upi  Volume.Of.Transaction.in.Mn  \
# count     5.00000               5.000000                     5.000000
# mean   2017.80000              96.600000                   421.357000
# std       1.30384              51.621701                   417.783663
# min    2016.00000              26.000000                     0.103000
# 25%    2017.00000              60.000000                    76.772000
# 50%    2018.00000             114.000000                   312.020000
# 75%    2019.00000             141.000000                   799.540000
# max    2019.00000             142.000000                   918.350000
#
#        Amount.Of.Transaction  Amount.Of.Transaction.In.Bn
# count               5.000000                     5.000000
# mean            69856.854000                   698.568540
# std             71190.604366                   711.906044
# min                48.600000                     0.486000
# ...

# %% [markdown]
# Here we can use `.sample()` to select a random data for calculating the % of error or to calculate the acuraccy rate of the data.
#
# By using `.describe()` we can calculate the percentile , mean  , min , max as we can see in the table.
#
# Note : Whenever we are geting a sample of data to calculate the acuraccy rate always `select a random values`
#        if we select a data with a particular requirement then it will notify as a `biased` data so always select a random values.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "dhirendrapathak63/eda-on-upi" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/dhirendrapathak63/eda-on-upi
# 'https://jovian.ml/dhirendrapathak63/eda-on-upi'

# %% [markdown]
# ## Inferences and Conclusion

# %% [markdown]
# The data which i perform contains a immense possibilities To improve our analytics. By solving problems Build more confidence
# to perform better. The ways in which questions can be asked varies, so does the way of tackling a problem.
# Only the one that has been minutely observed and tested will provide results worth trusting.

# %% [markdown]
# The various types of graphs are used here to show the data in better way. The plots which have been built in this project can be used in Various Analysis fields like educational, business related, Technical and Many other fields.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "dhirendrapathak63/eda-on-upi" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/dhirendrapathak63/eda-on-upi
# 'https://jovian.ml/dhirendrapathak63/eda-on-upi'

# %% [markdown]
# ## References and Future Work

# %% [markdown]
# ### References includes :
#
# The Official Links for the Matplotlib, Seaborn, Data World, Pandas Dataframes, Numpy are all have been included at the Top section.

# %% [markdown]
# ### Future Works includes :
#  Exited to learn more about the data analytics.
#
#  Implementing Machine Learning models.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "dhirendrapathak63/eda-on-upi" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/dhirendrapathak63/eda-on-upi
# 'https://jovian.ml/dhirendrapathak63/eda-on-upi'
